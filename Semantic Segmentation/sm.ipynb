# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras import backend as K


def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)





def multi_unet_model(n_classes=4, IMG_HEIGHT=256, IMG_WIDTH=256, IMG_CHANNELS=1):
#Build the model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.2)(c1)  # Original 0.1
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.2)(c2)  # Original 0.1
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)
     
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)
     
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)
     
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
    
    #Expansive path 
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
     
    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
     
    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.2)(c8)  # Original 0.1
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
     
    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.2)(c9)  # Original 0.1
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
     
    outputs = Conv2D(n_classes, (1, 1), activation='softmax')(c9)
     
    model = Model(inputs=[inputs], outputs=[outputs])
    
    #NOTE: Compile the model in the main program to make it easy to test with various loss functions
    #model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    #model.summary()
    
    return model

# %%
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt
from patchify import patchify
from PIL import Image
import segmentation_models as sm
from tensorflow.keras.metrics import MeanIoU
from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler = MinMaxScaler()

# %%
root_directory = '/home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset'


patch_size = 256

# %%
image_dataset = []  
for path, subdirs, files in os.walk(root_directory):
    #print(path)  
    dirname = path.split(os.path.sep)[-1]
    if dirname == 'images':   #Find all 'images' directories
        images = os.listdir(path)  #List of all image names in this subdirectory
        for i, image_name in enumerate(images):  
            if image_name.endswith(".jpg"):   #Only read jpg images...
               
                image = cv2.imread(path+"/"+image_name, 1)  #Read each image as BGR
                SIZE_X = (image.shape[1]//patch_size)*patch_size #Nearest size divisible by our patch size
                SIZE_Y = (image.shape[0]//patch_size)*patch_size #Nearest size divisible by our patch size
                image = Image.fromarray(image)
                image = image.crop((0 ,0, SIZE_X, SIZE_Y))  #Crop from top left corner
                image = image.resize((SIZE_X, SIZE_Y))  #Try not to resize for semantic segmentation
                image = np.array(image)             
       
                #Extract patches from each image
                print("Now patchifying image:", path+"/"+image_name)
                patches_img = patchify(image, (patch_size, patch_size, 3), step=patch_size)  #Step=256 for 256 patches means no overlap
        
                for i in range(patches_img.shape[0]):
                    for j in range(patches_img.shape[1]):
                        
                        single_patch_img = patches_img[i,j,:,:]
                        
                        #Use minmaxscaler instead of just dividing by 255. 
                        single_patch_img = scaler.fit_transform(single_patch_img.reshape(-1, single_patch_img.shape[-1])).reshape(single_patch_img.shape)
                        
                        #single_patch_img = (single_patch_img.astype('float32')) / 255. 
                        single_patch_img = single_patch_img[0] #Drop the extra unecessary dimension that patchify adds.                               
                        image_dataset.append(single_patch_img)
# Out:
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 8/images/image_part_005.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 8/images/image_part_009.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 8/images/image_part_001.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 8/images/image_part_008.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 8/images/image_part_004.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 8/images/image_part_003.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 8/images/image_part_007.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 8/images/image_part_006.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 8/images/image_part_002.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 6/images/image_part_005.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 6/images/image_part_009.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 6/images/image_part_001.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 6/images/image_part_008.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 6/images/image_part_004.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 6/images/image_part_003.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 6/images/image_part_007.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 6/images/image_part_006.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 6/images/image_part_002.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 2/images/image_part_005.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 2/images/image_part_009.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 2/images/image_part_001.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 2/images/image_part_008.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 2/images/image_part_004.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 2/images/image_part_003.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 2/images/image_part_007.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 2/images/image_part_006.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 2/images/image_part_002.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 4/images/image_part_005.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 4/images/image_part_009.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 4/images/image_part_001.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 4/images/image_part_008.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 4/images/image_part_004.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 4/images/image_part_003.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 4/images/image_part_007.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 4/images/image_part_006.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 4/images/image_part_002.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 3/images/image_part_005.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 3/images/image_part_009.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 3/images/image_part_001.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 3/images/image_part_008.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 3/images/image_part_004.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 3/images/image_part_003.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 3/images/image_part_007.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 3/images/image_part_006.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 3/images/image_part_002.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 1/images/image_part_005.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 1/images/image_part_009.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 1/images/image_part_001.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 1/images/image_part_008.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 1/images/image_part_004.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 1/images/image_part_003.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 1/images/image_part_007.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 1/images/image_part_006.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 1/images/image_part_002.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 7/images/image_part_005.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 7/images/image_part_009.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 7/images/image_part_001.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 7/images/image_part_008.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 7/images/image_part_004.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 7/images/image_part_003.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 7/images/image_part_007.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 7/images/image_part_006.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 7/images/image_part_002.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 5/images/image_part_005.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 5/images/image_part_009.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 5/images/image_part_001.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 5/images/image_part_008.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 5/images/image_part_004.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 5/images/image_part_003.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 5/images/image_part_007.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 5/images/image_part_006.jpg
# Now patchifying image: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 5/images/image_part_002.jpg

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
#Now do the same as above for masks
 #For this specific dataset we could have added masks to the above code as masks have extension png
mask_dataset = []  
for path, subdirs, files in os.walk(root_directory):
    #print(path)  
    dirname = path.split(os.path.sep)[-1]
    if dirname == 'masks':   #Find all 'images' directories
        masks = os.listdir(path)  #List of all image names in this subdirectory
        for i, mask_name in enumerate(masks):  
            if mask_name.endswith(".png"):   #Only read png images... (masks in this dataset)
               
                mask = cv2.imread(path+"/"+mask_name, 1)  #Read each image as Grey (or color but remember to map each color to an integer)
                mask = cv2.cvtColor(mask,cv2.COLOR_BGR2RGB)
                SIZE_X = (mask.shape[1]//patch_size)*patch_size #Nearest size divisible by our patch size
                SIZE_Y = (mask.shape[0]//patch_size)*patch_size #Nearest size divisible by our patch size
                mask = Image.fromarray(mask)
                mask = mask.crop((0 ,0, SIZE_X, SIZE_Y))  #Crop from top left corner
                mask = mask.resize((SIZE_X, SIZE_Y))  #Try not to resize for semantic segmentation
                mask = np.array(mask)             
       
                #Extract patches from each image
                print("Now patchifying mask:", path+"/"+mask_name)
                patches_mask = patchify(mask, (patch_size, patch_size, 3), step=patch_size)  #Step=256 for 256 patches means no overlap
        
                for i in range(patches_mask.shape[0]):
                    for j in range(patches_mask.shape[1]):
                        
                        single_patch_mask = patches_mask[i,j,:,:]
                        #single_patch_img = (single_patch_img.astype('float32')) / 255. #No need to scale masks, but you can do it if you want
                        single_patch_mask = single_patch_mask[0] #Drop the extra unecessary dimension that patchify adds.                               
                        mask_dataset.append(single_patch_mask)
# Out:
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 8/masks/image_part_002.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 8/masks/image_part_006.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 8/masks/image_part_005.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 8/masks/image_part_008.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 8/masks/image_part_004.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 8/masks/image_part_001.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 8/masks/image_part_003.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 8/masks/image_part_007.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 8/masks/image_part_009.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 6/masks/image_part_002.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 6/masks/image_part_006.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 6/masks/image_part_005.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 6/masks/image_part_008.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 6/masks/image_part_004.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 6/masks/image_part_001.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 6/masks/image_part_003.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 6/masks/image_part_007.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 6/masks/image_part_009.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 2/masks/image_part_002.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 2/masks/image_part_006.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 2/masks/image_part_005.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 2/masks/image_part_008.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 2/masks/image_part_004.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 2/masks/image_part_001.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 2/masks/image_part_003.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 2/masks/image_part_007.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 2/masks/image_part_009.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 4/masks/image_part_002.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 4/masks/image_part_006.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 4/masks/image_part_005.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 4/masks/image_part_008.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 4/masks/image_part_004.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 4/masks/image_part_001.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 4/masks/image_part_003.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 4/masks/image_part_007.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 4/masks/image_part_009.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 3/masks/image_part_002.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 3/masks/image_part_006.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 3/masks/image_part_005.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 3/masks/image_part_008.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 3/masks/image_part_004.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 3/masks/image_part_001.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 3/masks/image_part_003.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 3/masks/image_part_007.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 3/masks/image_part_009.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 1/masks/image_part_002.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 1/masks/image_part_006.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 1/masks/image_part_005.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 1/masks/image_part_008.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 1/masks/image_part_004.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 1/masks/image_part_001.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 1/masks/image_part_003.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 1/masks/image_part_007.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 1/masks/image_part_009.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 7/masks/image_part_002.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 7/masks/image_part_006.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 7/masks/image_part_005.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 7/masks/image_part_008.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 7/masks/image_part_004.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 7/masks/image_part_001.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 7/masks/image_part_003.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 7/masks/image_part_007.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 7/masks/image_part_009.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 5/masks/image_part_002.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 5/masks/image_part_006.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 5/masks/image_part_005.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 5/masks/image_part_008.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 5/masks/image_part_004.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 5/masks/image_part_001.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 5/masks/image_part_003.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 5/masks/image_part_007.png
# Now patchifying mask: /home/mdsamiul/InSAR-Coding/Data/Semantic segmentation dataset/Tile 5/masks/image_part_009.png

# %%
image_dataset = np.array(image_dataset)
mask_dataset =  np.array(mask_dataset)

#Sanity check, view few mages
import random
import numpy as np

image_number = random.randint(0, len(image_dataset))
print(image_number)
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(np.reshape(image_dataset[image_number], (patch_size, patch_size, 3)))
plt.subplot(122)
plt.imshow(np.reshape(mask_dataset[image_number], (patch_size, patch_size, 3)))
plt.show()
# Out:
# 41

# %%
#@title Default title text
a=int('3C', 16)  #3C with base 16. Should return 60. 
print(a)
#Do the same for all RGB channels in each hex code to convert to RGB
Building = '#3C1098'.lstrip('#')
Building = np.array(tuple(int(Building[i:i+2], 16) for i in (0, 2, 4))) # 60, 16, 152

Land = '#8429F6'.lstrip('#')
Land = np.array(tuple(int(Land[i:i+2], 16) for i in (0, 2, 4))) #132, 41, 246

Road = '#6EC1E4'.lstrip('#') 
Road = np.array(tuple(int(Road[i:i+2], 16) for i in (0, 2, 4))) #110, 193, 228

Vegetation =  'FEDD3A'.lstrip('#') 
Vegetation = np.array(tuple(int(Vegetation[i:i+2], 16) for i in (0, 2, 4))) #254, 221, 58

Water = 'E2A929'.lstrip('#') 
Water = np.array(tuple(int(Water[i:i+2], 16) for i in (0, 2, 4))) #226, 169, 41

Unlabeled = '#9B9B9B'.lstrip('#') 
Unlabeled = np.array(tuple(int(Unlabeled[i:i+2], 16) for i in (0, 2, 4))) #155, 155, 155

label = single_patch_mask

# Now replace RGB to integer values to be used as labels.
#Find pixels with combination of RGB for the above defined arrays...
#if matches then replace all values in that pixel with a specific integer
def rgb_to_2D_label(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    label_seg [np.all(label == Building,axis=-1)] = 0
    label_seg [np.all(label==Land,axis=-1)] = 1
    label_seg [np.all(label==Road,axis=-1)] = 2
    label_seg [np.all(label==Vegetation,axis=-1)] = 3
    label_seg [np.all(label==Water,axis=-1)] = 4
    label_seg [np.all(label==Unlabeled,axis=-1)] = 5
    
    label_seg = label_seg[:,:,0]  #Just take the first channel, no need for all 3 channels
    
    return label_seg

labels = []
for i in range(mask_dataset.shape[0]):
    label = rgb_to_2D_label(mask_dataset[i])
    labels.append(label)    

labels = np.array(labels)   
labels = np.expand_dims(labels, axis=3)
 

print("Unique labels in label dataset are: ", np.unique(labels))

#Another Sanity check, view few mages
import random
import numpy as np
image_number = random.randint(0, len(image_dataset))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(image_dataset[image_number])
plt.subplot(122)
plt.imshow(labels[image_number][:,:,0])
plt.show()
# Out:
# 60
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Unique labels in label dataset are:  [0 1 2 3 4 5]

# %%
n_classes = len(np.unique(labels))
from tensorflow.keras.utils import to_categorical
labels_cat = to_categorical(labels, num_classes=n_classes)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(image_dataset, labels_cat, test_size = 0.20, random_state = 42)

weights = [0.1666, 0.1666, 0.1666, 0.1666, 0.1666, 0.1666]
dice_loss = sm.losses.DiceLoss(class_weights=weights) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)  #


IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH  = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]

# from simple_multi_unet_model import multi_unet_model, jacard_coef  

metrics=['accuracy', jacard_coef]

def get_model():
    return multi_unet_model(n_classes=n_classes, IMG_HEIGHT=IMG_HEIGHT, IMG_WIDTH=IMG_WIDTH, IMG_CHANNELS=IMG_CHANNELS)

model = get_model()
model.compile(optimizer='adam', loss=total_loss, metrics=metrics)
#model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=metrics)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 16) 448         input_3[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 256, 256, 16) 0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 16) 2320        dropout_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 128, 128, 16) 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 32) 4640        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 128, 128, 32) 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 32) 9248        dropout_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 64, 64, 32)   0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 64)   18496       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 64, 64, 64)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 64)   36928       dropout_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 32, 32, 64)   0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 128)  73856       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 32, 32, 128)  0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 128)  147584      dropout_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 16, 16, 128)  0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 16, 16, 256)  295168      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 16, 16, 256)  0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 256)  590080      dropout_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 128)  131200      conv2d_26[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 256)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 32, 32, 128)  0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 128)  147584      dropout_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 64)   32832       conv2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 64, 64, 64)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 64, 64)   36928       dropout_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 32) 8224        conv2d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 128, 128, 32) 0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 128, 128, 32) 9248        dropout_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 256, 256, 16) 2064        conv2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 32) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 256, 256, 16) 4624        concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 256, 256, 16) 0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 256, 256, 16) 2320        dropout_17[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 256, 256, 6)  102         conv2d_34[0][0]
# ==================================================================================================
# Total params: 1,941,190
# Trainable params: 1,941,190
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
labels = []
for i in range(mask_dataset.shape[0]):
    label = rgb_to_2D_label(mask_dataset[i])
    labels.append(label)    

labels = np.array(labels)   
labels = np.expand_dims(labels, axis=3)
 

print("Unique labels in label dataset are: ", np.unique(labels))
# Out:
# Unique labels in label dataset are:  [0 1 2 3 4 5]

# %%
import random
import numpy as np
image_number = random.randint(0, len(image_dataset))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(image_dataset[image_number])
plt.subplot(122)
plt.imshow(labels[image_number][:,:,0])
plt.show()

n_classes = len(np.unique(labels))
from keras.utils import to_categorical
labels_cat = to_categorical(labels, num_classes=n_classes)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(image_dataset, labels_cat, test_size = 0.20, random_state = 42)


#######################################
#Parameters for model
# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
# set class weights for dice_loss
# from sklearn.utils.class_weight import compute_class_weight

# weights = compute_class_weight('balanced', np.unique(np.ravel(labels,order='C')), 
#                               np.ravel(labels,order='C'))
# print(weights)

weights = [0.1666, 0.1666, 0.1666, 0.1666, 0.1666, 0.1666]
dice_loss = sm.losses.DiceLoss(class_weights=weights) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)  #


IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH  = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]

#from simple_multi_unet_model import multi_unet_model, jacard_coef  

metrics=['accuracy', jacard_coef]

def get_model():
    return multi_unet_model(n_classes=n_classes, IMG_HEIGHT=IMG_HEIGHT, IMG_WIDTH=IMG_WIDTH, IMG_CHANNELS=IMG_CHANNELS)

model = get_model()
model.compile(optimizer='adam', loss=total_loss, metrics=metrics)

model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 256, 256, 16) 448         input_4[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 256, 256, 16) 0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 256, 256, 16) 2320        dropout_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 128, 128, 16) 0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 128, 128, 32) 4640        max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 128, 128, 32) 0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 128, 128, 32) 9248        dropout_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 64, 64, 32)   0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 64, 64, 64)   18496       max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 64, 64, 64)   0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 64, 64, 64)   36928       dropout_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 32, 32, 64)   0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 32, 32, 128)  73856       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 32, 32, 128)  0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 32, 32, 128)  147584      dropout_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 16, 16, 128)  0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 16, 16, 256)  295168      max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 16, 16, 256)  0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 16, 16, 256)  590080      dropout_22[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 32, 32, 128)  131200      conv2d_45[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 256)  0           conv2d_transpose_5[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 32, 32, 128)  0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 128)  147584      dropout_23[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 64, 64, 64)   32832       conv2d_47[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_6[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_6[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 64, 64, 64)   0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 64, 64, 64)   36928       dropout_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 128, 128, 32) 8224        conv2d_49[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_7[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_7[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 128, 128, 32) 0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 128, 128, 32) 9248        dropout_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 256, 256, 16) 2064        conv2d_51[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 256, 256, 32) 0           conv2d_transpose_8[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 256, 256, 16) 4624        concatenate_8[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 256, 256, 16) 0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 256, 256, 16) 2320        dropout_26[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 256, 256, 6)  102         conv2d_53[0][0]
# ==================================================================================================
# Total params: 1,941,190
# Trainable params: 1,941,190
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history1 = model.fit(X_train, y_train, 
                    batch_size = 16, 
                    verbose=1, 
                    epochs=100, 
                    validation_data=(X_test, y_test), 
                    shuffle=False)
# Out:
# WARNING:tensorflow:From /home/mdsamiul/anaconda3/envs/tf-gpu-cuda8/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 1044 samples, validate on 261 samples
# Epoch 1/100
# 1044/1044 [==============================] - 15s 15ms/step - loss: 1.0109 - accuracy: 0.5097 - jacard_coef: 0.1818 - val_loss: 1.0074 - val_accuracy: 0.5241 - val_jacard_coef: 0.1788
# Epoch 2/100
# 1044/1044 [==============================] - 11s 11ms/step - loss: 1.0069 - accuracy: 0.5349 - jacard_coef: 0.1923 - val_loss: 1.0063 - val_accuracy: 0.5241 - val_jacard_coef: 0.1804
# Epoch 3/100
# 1044/1044 [==============================] - 11s 11ms/step - loss: 1.0050 - accuracy: 0.5312 - jacard_coef: 0.1992 - val_loss: 1.0039 - val_accuracy: 0.5137 - val_jacard_coef: 0.1908
# Epoch 4/100
# 1044/1044 [==============================] - 11s 11ms/step - loss: 1.0027 - accuracy: 0.5296 - jacard_coef: 0.2083 - val_loss: 1.0028 - val_accuracy: 0.5185 - val_jacard_coef: 0.1907
# Epoch 5/100
# 1044/1044 [==============================] - 11s 11ms/step - loss: 1.0019 - accuracy: 0.5273 - jacard_coef: 0.2115 - val_loss: 1.0023 - val_accuracy: 0.5186 - val_jacard_coef: 0.1969
# Epoch 6/100
# 1044/1044 [==============================] - 11s 11ms/step - loss: 1.0014 - accuracy: 0.5279 - jacard_coef: 0.2136 - val_loss: 1.0020 - val_accuracy: 0.5204 - val_jacard_coef: 0.1990
# Epoch 7/100
# 1044/1044 [==============================] - 11s 11ms/step - loss: 1.0011 - accuracy: 0.5289 - jacard_coef: 0.2151 - val_loss: 1.0018 - val_accuracy: 0.5185 - val_jacard_coef: 0.2014
# Epoch 8/100
# 1044/1044 [==============================] - 11s 11ms/step - loss: 1.0006 - accuracy: 0.5268 - jacard_coef: 0.2168 - val_loss: 1.0014 - val_accuracy: 0.5175 - val_jacard_coef: 0.1997
# Epoch 9/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 1.0002 - accuracy: 0.5265 - jacard_coef: 0.2188 - val_loss: 1.0012 - val_accuracy: 0.5150 - val_jacard_coef: 0.2036
# Epoch 10/100
# 1044/1044 [==============================] - 11s 11ms/step - loss: 0.9997 - accuracy: 0.5236 - jacard_coef: 0.2199 - val_loss: 1.0009 - val_accuracy: 0.5126 - val_jacard_coef: 0.1967
# Epoch 11/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9995 - accuracy: 0.5261 - jacard_coef: 0.2211 - val_loss: 1.0006 - val_accuracy: 0.5060 - val_jacard_coef: 0.1976
# Epoch 12/100
# 1044/1044 [==============================] - 11s 11ms/step - loss: 0.9991 - accuracy: 0.5250 - jacard_coef: 0.2222 - val_loss: 1.0003 - val_accuracy: 0.5031 - val_jacard_coef: 0.1988
# Epoch 13/100
# 1044/1044 [==============================] - 11s 11ms/step - loss: 0.9989 - accuracy: 0.5249 - jacard_coef: 0.2232 - val_loss: 1.0001 - val_accuracy: 0.5019 - val_jacard_coef: 0.1986
# Epoch 14/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9987 - accuracy: 0.5268 - jacard_coef: 0.2245 - val_loss: 1.0000 - val_accuracy: 0.4991 - val_jacard_coef: 0.1997
# Epoch 15/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9985 - accuracy: 0.5263 - jacard_coef: 0.2255 - val_loss: 0.9998 - val_accuracy: 0.5002 - val_jacard_coef: 0.2002
# Epoch 16/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9982 - accuracy: 0.5276 - jacard_coef: 0.2258 - val_loss: 0.9993 - val_accuracy: 0.5074 - val_jacard_coef: 0.2031
# Epoch 17/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9979 - accuracy: 0.5279 - jacard_coef: 0.2278 - val_loss: 0.9988 - val_accuracy: 0.5112 - val_jacard_coef: 0.2039
# Epoch 18/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9974 - accuracy: 0.5275 - jacard_coef: 0.2292 - val_loss: 0.9985 - val_accuracy: 0.5157 - val_jacard_coef: 0.2088
# Epoch 19/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9971 - accuracy: 0.5298 - jacard_coef: 0.2305 - val_loss: 0.9981 - val_accuracy: 0.5146 - val_jacard_coef: 0.2090
# Epoch 20/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9968 - accuracy: 0.5292 - jacard_coef: 0.2318 - val_loss: 0.9979 - val_accuracy: 0.5167 - val_jacard_coef: 0.2130
# Epoch 21/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9965 - accuracy: 0.5314 - jacard_coef: 0.2333 - val_loss: 0.9976 - val_accuracy: 0.5166 - val_jacard_coef: 0.2165
# Epoch 22/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9963 - accuracy: 0.5318 - jacard_coef: 0.2344 - val_loss: 0.9971 - val_accuracy: 0.5157 - val_jacard_coef: 0.2200
# Epoch 23/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9960 - accuracy: 0.5330 - jacard_coef: 0.2353 - val_loss: 0.9971 - val_accuracy: 0.5168 - val_jacard_coef: 0.2213
# Epoch 24/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9957 - accuracy: 0.5331 - jacard_coef: 0.2366 - val_loss: 0.9969 - val_accuracy: 0.5172 - val_jacard_coef: 0.2222
# Epoch 25/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9956 - accuracy: 0.5332 - jacard_coef: 0.2371 - val_loss: 0.9967 - val_accuracy: 0.5167 - val_jacard_coef: 0.2238
# Epoch 26/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9955 - accuracy: 0.5333 - jacard_coef: 0.2372 - val_loss: 0.9967 - val_accuracy: 0.5172 - val_jacard_coef: 0.2249
# Epoch 27/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9954 - accuracy: 0.5330 - jacard_coef: 0.2381 - val_loss: 0.9966 - val_accuracy: 0.5165 - val_jacard_coef: 0.2258
# Epoch 28/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9953 - accuracy: 0.5335 - jacard_coef: 0.2382 - val_loss: 0.9964 - val_accuracy: 0.5152 - val_jacard_coef: 0.2245
# Epoch 29/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9950 - accuracy: 0.5340 - jacard_coef: 0.2393 - val_loss: 0.9962 - val_accuracy: 0.5161 - val_jacard_coef: 0.2267
# Epoch 30/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9949 - accuracy: 0.5342 - jacard_coef: 0.2396 - val_loss: 0.9959 - val_accuracy: 0.5181 - val_jacard_coef: 0.2266
# Epoch 31/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9948 - accuracy: 0.5340 - jacard_coef: 0.2403 - val_loss: 0.9958 - val_accuracy: 0.5199 - val_jacard_coef: 0.2290
# Epoch 32/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9945 - accuracy: 0.5358 - jacard_coef: 0.2415 - val_loss: 0.9953 - val_accuracy: 0.5197 - val_jacard_coef: 0.2305
# Epoch 33/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9946 - accuracy: 0.5349 - jacard_coef: 0.2411 - val_loss: 0.9955 - val_accuracy: 0.5229 - val_jacard_coef: 0.2280
# Epoch 34/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9941 - accuracy: 0.5366 - jacard_coef: 0.2428 - val_loss: 0.9950 - val_accuracy: 0.5222 - val_jacard_coef: 0.2303
# Epoch 35/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9938 - accuracy: 0.5392 - jacard_coef: 0.2443 - val_loss: 0.9949 - val_accuracy: 0.5214 - val_jacard_coef: 0.2303
# Epoch 36/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9937 - accuracy: 0.5376 - jacard_coef: 0.2443 - val_loss: 0.9948 - val_accuracy: 0.5255 - val_jacard_coef: 0.2315
# Epoch 37/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9935 - accuracy: 0.5389 - jacard_coef: 0.2453 - val_loss: 0.9945 - val_accuracy: 0.5275 - val_jacard_coef: 0.2321
# Epoch 38/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9931 - accuracy: 0.5404 - jacard_coef: 0.2467 - val_loss: 0.9947 - val_accuracy: 0.5258 - val_jacard_coef: 0.2336
# Epoch 39/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9931 - accuracy: 0.5413 - jacard_coef: 0.2469 - val_loss: 0.9945 - val_accuracy: 0.5260 - val_jacard_coef: 0.2317
# Epoch 40/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9927 - accuracy: 0.5426 - jacard_coef: 0.2484 - val_loss: 0.9948 - val_accuracy: 0.5240 - val_jacard_coef: 0.2289
# Epoch 41/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9927 - accuracy: 0.5432 - jacard_coef: 0.2489 - val_loss: 0.9955 - val_accuracy: 0.5219 - val_jacard_coef: 0.2338
# Epoch 42/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9926 - accuracy: 0.5417 - jacard_coef: 0.2490 - val_loss: 0.9945 - val_accuracy: 0.5178 - val_jacard_coef: 0.2301
# Epoch 43/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9925 - accuracy: 0.5437 - jacard_coef: 0.2497 - val_loss: 0.9943 - val_accuracy: 0.5257 - val_jacard_coef: 0.2352
# Epoch 44/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9921 - accuracy: 0.5439 - jacard_coef: 0.2513 - val_loss: 0.9938 - val_accuracy: 0.5251 - val_jacard_coef: 0.2361
# Epoch 45/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9920 - accuracy: 0.5454 - jacard_coef: 0.2517 - val_loss: 0.9938 - val_accuracy: 0.5261 - val_jacard_coef: 0.2333
# Epoch 46/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9920 - accuracy: 0.5454 - jacard_coef: 0.2511 - val_loss: 0.9953 - val_accuracy: 0.5138 - val_jacard_coef: 0.2290
# Epoch 47/100
# 1044/1044 [==============================] - 12s 11ms/step - loss: 0.9920 - accuracy: 0.5454 - jacard_coef: 0.2516 - val_loss: 0.9957 - val_accuracy: 0.5012 - val_jacard_coef: 0.2304
# Epoch 48/100
# 1040/1044 [============================>.] - ETA: 0s - loss: 0.9916 - accuracy: 0.5446 - jacard_coef: 0.2526

# %%
model.save('models/satellite_standard_unet_100epochs_7May2021.hdf5')

# %%
#plot the training and validation accuracy and loss at each epoch
history = history1
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['jacard_coef']
val_acc = history.history['val_jacard_coef']

plt.plot(epochs, acc, 'y', label='Training IoU')
plt.plot(epochs, val_acc, 'r', label='Validation IoU')
plt.title('Training and validation IoU')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()

# %%
from keras.models import load_model
model = load_model("/home/mdsamiul/InSAR-Coding/Semantic Segmentation/satellite_standard_unet_100epochs_7May2021.hdf5",compile=False)
                   

#IOU
y_pred=model.predict(X_test)
y_pred_argmax=np.argmax(y_pred, axis=3)
y_test_argmax=np.argmax(y_test, axis=3)

# %%
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test_argmax[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img)
plt.subplot(232)

plt.title('Prediction on test image')
plt.imshow(predicted_img)
plt.savefig("/home/mdsamiul/InSAR-Coding/Semantic Segmentation/test_prediction5")
